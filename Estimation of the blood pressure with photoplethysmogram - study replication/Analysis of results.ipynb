# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import os 

pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)

# %%
def process(results_sp,results_dp):
    '''Combines results from the paper and ours in order to compare them side by side'''
    pd.set_option('display.max_colwidth', 1) 
    best_results_dp = results_dp.groupby('Model').apply(lambda df: df.iloc[df['Overall score'].idxmax(),1:]).reset_index()
    display(best_results_dp)
    best_results_dp.drop(['Parameters','Number of features'],axis=1,inplace=True)
    best_results_dp.columns = ['Model', 'MAE_DP', 'ME_DP', 'SE_DP', 'MASE_DP']

    best_results_sp = results_sp.groupby('Model').apply(lambda df: df.iloc[df['Overall score'].idxmax(),1:]).reset_index()
    display(best_results_sp)
    best_results_sp.drop(['Parameters','Number of features'],axis=1,inplace=True)
    best_results_sp.columns = ['Model', 'MAE_SP', 'ME_SP', 'SE_SP', 'MASE_SP']

    best_results = best_results_sp.merge(best_results_dp,on='Model').round(2)
    
    return best_results

# %% [markdown]
# ## Preprocessing of input data

# %%
results_dp_bcg_1 = pd.read_csv('results_dp_bcg_11_15.csv',index_col =0)
results_dp_bcg_2 = pd.read_csv('results_dp_bcg_13_24.csv',index_col=0)
results_dp_bcg = pd.concat([results_dp_bcg_1,results_dp_bcg_2])

results_dp_ppgbp_1 = pd.read_csv('results_dp_ppgbp_12_10.csv',index_col =0)
results_dp_ppgbp_2 = pd.read_csv('results_dp_ppgbp_13_53.csv',index_col=0)
results_dp_ppgbp = pd.concat([results_dp_ppgbp_1,results_dp_ppgbp_2])

results_dp_sensor_1 = pd.read_csv('results_dp_sensor_04_38.csv',index_col =0)
results_dp_sensor_2 = pd.read_csv('results_dp_sensor_13_14.csv',index_col=0)
results_dp_sensor = pd.concat([results_dp_sensor_1,results_dp_sensor_2])

results_sp_bcg_1 = pd.read_csv('results_sp_bcg_11_15.csv',index_col =0)
results_sp_bcg_2 = pd.read_csv('results_sp_bcg_13_24.csv',index_col=0)
results_sp_bcg = pd.concat([results_sp_bcg_1,results_sp_bcg_2])

results_sp_ppgbp_1 = pd.read_csv('results_sp_ppgbp_12_10.csv',index_col =0)
results_sp_ppgbp_2 = pd.read_csv('results_sp_ppgbp_13_53.csv',index_col=0)
results_sp_ppgbp = pd.concat([results_sp_ppgbp_1,results_sp_ppgbp_2])

results_sp_sensor_1 = pd.read_csv('results_sp_sensor_04_38.csv',index_col =0)
results_sp_sensor_2 = pd.read_csv('results_sp_sensor_13_14.csv',index_col=0)
results_sp_sensor = pd.concat([results_sp_sensor_1,results_sp_sensor_2])


results_dp_bcg['Overall score'] = results_dp_bcg['Overall score'] * (-1) 
results_sp_bcg['Overall score'] = results_sp_bcg['Overall score'] * (-1) 
results_dp_ppgbp['Overall score'] = results_dp_ppgbp['Overall score'] * (-1) 
results_sp_ppgbp['Overall score'] = results_sp_ppgbp['Overall score'] * (-1) 
results_dp_sensor['Overall score'] = results_dp_sensor['Overall score'] * (-1) 
results_sp_sensor['Overall score'] = results_sp_sensor['Overall score'] * (-1) 

results_dp_bcg['MASE'] = results_dp_bcg['MASE'] * (-100) 
results_sp_bcg['MASE'] = results_sp_bcg['MASE'] * (-100) 
results_dp_ppgbp['MASE'] = results_dp_ppgbp['MASE'] * (-100) 
results_sp_ppgbp['MASE'] = results_sp_ppgbp['MASE'] * (-100) 
results_dp_sensor['MASE'] = results_dp_sensor['MASE'] * (-100) 
results_sp_sensor['MASE'] = results_sp_sensor['MASE'] * (-100) 

results_dp_bcg = results_dp_bcg.round(2)
results_sp_bcg = results_sp_bcg.round(2)
results_dp_ppgbp = results_dp_ppgbp.round(2)
results_sp_ppgbp = results_sp_ppgbp.round(2)
results_sp_sensor = results_sp_sensor.round(2)
results_dp_sensor = results_dp_sensor.round(2)


results_dp_bcg.Parameters = results_dp_bcg.Parameters.str.replace("'activation': 'relu',",'').str.replace(", 'learning_rate': 'adaptive', 'max_iter': 400, 'solver': 'adam'",'')
results_sp_bcg.Parameters = results_sp_bcg.Parameters.str.replace("'activation': 'relu',",'').str.replace(", 'learning_rate': 'adaptive', 'max_iter': 400, 'solver': 'adam'",'')
results_dp_ppgbp.Parameters = results_dp_ppgbp.Parameters.str.replace("'activation': 'relu',",'').str.replace(", 'learning_rate': 'adaptive', 'max_iter': 400, 'solver': 'adam'",'')
results_sp_ppgbp.Parameters = results_sp_ppgbp.Parameters.str.replace("'activation': 'relu',",'').str.replace(", 'learning_rate': 'adaptive', 'max_iter': 400, 'solver': 'adam'",'')
results_sp_sensor.Parameters = results_sp_sensor.Parameters.str.replace("'activation': 'relu',",'').str.replace(", 'learning_rate': 'adaptive', 'max_iter': 400, 'solver': 'adam'",'')
results_dp_sensor.Parameters = results_dp_sensor.Parameters.str.replace("'activation': 'relu',",'').str.replace(", 'learning_rate': 'adaptive', 'max_iter': 400, 'solver': 'adam'",'')

# %% [markdown]
# ## Sensor data

# %%
data = {
    'Model': ['SVR()_paper', 'RandomForestRegressor()_paper', 'MLPRegressor()_paper'],
    'MAE_SP': [15.60, 15.86, 16.03],
    'ME_SE_SP': ['-0.00±19.68', '-0.12±19.85', '-0.50±20.10'],
    'MASE_SP': [88.62, 90.08, 91.03],
    'MAE_DP': [7.50, 7.66, 7.77],
    'ME_SE_DP': ['-1.45±9.81', '-0.03±9.86', '-0.19±10.04'],
    'MASE_DP': [90.76, 92.63, 94.05]
}
paper_sensor = pd.DataFrame(data)

# Split the 'ME_SE' column into two separate columns
paper_sensor[['ME_SP', 'SE_SP']] = paper_sensor['ME_SE_SP'].str.split('±', expand=True).astype(float)
paper_sensor[['ME_DP', 'SE_DP']] = paper_sensor['ME_SE_DP'].str.split('±', expand=True).astype(float)
paper_sensor.drop(['ME_SE_SP', 'ME_SE_DP'], axis=1, inplace=True)
paper_sensor = paper_sensor[['Model', 'MAE_SP', 'ME_SP', 'SE_SP', 'MASE_SP', 'MAE_DP', 'ME_DP', 'SE_DP', 'MASE_DP']]

# %%
print('Results for the Sensor dataset \n')
print('Results of DP')
display(results_dp_sensor.sort_values(by = 'Overall score'))
print('Results of SP')
display(results_sp_sensor.sort_values(by = 'Overall score'))
# Out:
# Results for the Sensor dataset
#
# Results of DP
#                      Model                                         Parameters  \
# 0                    SVR()        {'C': 100, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0                    SVR()      {'C': 10, 'epsilon': 0.2, 'kernel': 'linear'}
# 0                    SVR()     {'C': 100, 'epsilon': 0.1, 'kernel': 'linear'}
# 0                    SVR()      {'C': 10, 'epsilon': 0.3, 'kernel': 'linear'}
# 0                    SVR()        {'C': 100, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0                    SVR()     {'C': 100, 'epsilon': 0.2, 'kernel': 'linear'}
# 0                    SVR()        {'C': 100, 'epsilon': 0.2, 'kernel': 'rbf'}
# 1           MLPRegressor()    { 'alpha': 0.1, 'hidden_layer_sizes': (25, 25)}
# 0                    SVR()       {'C': 1, 'epsilon': 0.1, 'kernel': 'linear'}
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 5, 'n_e...
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 5, 'n_e...
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 2, 'n_e...
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 2, 'n_e...
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 2, 'n_e...
# 1           MLPRegressor()    { 'alpha': 0.1, 'hidden_layer_sizes': (25, 25)}
# 1           MLPRegressor()      { 'alpha': 0.01, 'hidden_layer_sizes': (25,)}
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 10, 'n_...
# 1           MLPRegressor()    { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1           MLPRegressor()   { 'alpha': 0.01, 'hidden_layer_sizes': (50, 25)}
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 5, 'n_e...
# 0                    SVR()        {'C': 100, 'epsilon': 0.3, 'kernel': 'rbf'}
# 1           MLPRegressor()   { 'alpha': 0.01, 'hidden_layer_sizes': (50, 25)}
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 2, 'n_e...
# 1           MLPRegressor()    { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1           MLPRegressor()   { 'alpha': 0.01, 'hidden_layer_sizes': (50, 25)}
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 5, 'n_e...
# 1           MLPRegressor()    { 'alpha': 0.1, 'hidden_layer_sizes': (25, 25)}
#
#    Number of features  Overall score    ME     SD   MASE
# 0                  20           7.56 -1.73   9.65  91.61
# 0                 100           7.59 -1.65   9.68  91.88
# 0                  50           7.60 -1.68   9.71  92.00
# 0                 150           7.61 -1.66   9.65  92.12
# 0                   8           7.61 -1.68   9.73  92.11
# 0                  16           7.62 -1.74   9.84  92.24
# 0                  12           7.63 -1.76   9.76  92.38
# 1                  20           7.63  0.79   9.77  92.39
# 0                 200           7.63 -1.65   9.68  92.37
# 2                  50           7.64 -0.04   7.37  92.51
# 2                 150           7.65 -0.03   7.36  92.68
# 2                 100           7.65 -0.06   7.29  92.60
# 2                  20           7.66 -0.03   7.44  92.71
# 2                 200           7.66 -0.05   7.29  92.78
# 1                 100           7.68  0.17   9.60  93.04
# 1                 150           7.68  0.46   9.52  93.01
# 2                  12           7.69  0.02   7.85  93.11
# 1                 200           7.69  1.68   9.52  93.14
# 1                  16           7.69  0.02   9.80  93.19
# 2                  16           7.69  0.00   7.56  93.14
# 0                   4           7.70 -1.77   9.88  93.23
# 1                   8           7.71  0.13   9.84  93.43
# 2                   8           7.73 -0.02   7.80  93.58
# 1                  12           7.73  0.16   9.87  93.58
# 1                  50           7.73  0.63   9.45  93.65
# 2                   4           7.82  0.00   8.40  94.71
# 1                   4           7.84  0.04  10.06  94.95
# Results of SP
#                      Model                                         Parameters  \
# 2  RandomForestRegressor()  {'max_depth': None, 'min_samples_split': 5, 'n...
# 2  RandomForestRegressor()  {'max_depth': 20, 'min_samples_split': 10, 'n_...
# 2  RandomForestRegressor()  {'max_depth': None, 'min_samples_split': 10, '...
# 2  RandomForestRegressor()  {'max_depth': None, 'min_samples_split': 2, 'n...
# 0                    SVR()     {'C': 100, 'epsilon': 0.1, 'kernel': 'linear'}
# 0                    SVR()     {'C': 100, 'epsilon': 0.1, 'kernel': 'linear'}
# 0                    SVR()     {'C': 100, 'epsilon': 0.3, 'kernel': 'linear'}
# 1           MLPRegressor()   { 'alpha': 0.01, 'hidden_layer_sizes': (25, 25)}
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 2, 'n_e...
# 0                    SVR()     {'C': 100, 'epsilon': 0.3, 'kernel': 'linear'}
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 5, 'n_e...
# 1           MLPRegressor()    { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1           MLPRegressor()   { 'alpha': 0.01, 'hidden_layer_sizes': (25, 25)}
# 1           MLPRegressor()   { 'alpha': 0.01, 'hidden_layer_sizes': (25, 25)}
# 1           MLPRegressor()    { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 10, 'n_...
# 0                    SVR()     {'C': 100, 'epsilon': 0.3, 'kernel': 'linear'}
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 2, 'n_e...
# 1           MLPRegressor()      { 'alpha': 0.01, 'hidden_layer_sizes': (50,)}
# 0                    SVR()     {'C': 100, 'epsilon': 0.3, 'kernel': 'linear'}
# 0                    SVR()        {'C': 100, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0                    SVR()        {'C': 100, 'epsilon': 0.2, 'kernel': 'rbf'}
# 1           MLPRegressor()    { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1           MLPRegressor()    { 'alpha': 0.1, 'hidden_layer_sizes': (25, 25)}
# 2  RandomForestRegressor()  {'max_depth': 10, 'min_samples_split': 2, 'n_e...
# 0                    SVR()        {'C': 100, 'epsilon': 0.1, 'kernel': 'rbf'}
# 1           MLPRegressor()    { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
#
#    Number of features  Overall score    ME     SD   MASE
# 2                 150          15.64  0.04   7.56  89.02
# 2                 200          15.65  0.05   9.15  89.08
# 2                 100          15.65  0.06   8.99  89.02
# 2                  50          15.69  0.06   7.04  89.26
# 0                 100          15.75 -0.53  19.39  89.59
# 0                 200          15.76 -0.19  19.23  89.66
# 0                 150          15.77 -0.55  19.27  89.74
# 1                 200          15.80  0.76  19.07  89.88
# 2                  20          15.82  0.00  15.49  89.99
# 0                  50          15.86 -0.56  19.65  90.24
# 2                  16          15.87 -0.01  15.79  90.32
# 1                 150          15.87 -1.68  19.20  90.28
# 1                 100          15.98 -0.33  19.27  90.92
# 1                  50          15.98 -0.11  19.64  90.91
# 1                  20          16.07 -0.26  19.98  91.46
# 2                  12          16.08 -0.01  16.52  91.47
# 0                  20          16.09 -0.49  20.07  91.58
# 2                   8          16.21  0.00  16.65  92.26
# 1                  16          16.31 -0.25  20.12  92.83
# 0                  16          16.38 -0.49  20.29  93.18
# 0                   8          16.52 -0.57  20.35  94.00
# 0                  12          16.61 -0.59  20.38  94.48
# 1                  12          16.64 -0.22  20.60  94.67
# 1                   8          16.65  0.58  20.61  94.76
# 2                   4          16.71 -0.05  18.11  95.08
# 0                   4          16.96 -0.78  20.83  96.51
# 1                   4          17.00 -0.64  20.56  96.75

# %%
best_results_sensor = process(results_sp_sensor,results_dp_sensor)
best_results_sensor
# Out:
# C:\Users\ilija\AppData\Local\Temp\ipykernel_2256\1944453032.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_results_dp = results_dp.groupby('Model').apply(lambda df: df.iloc[df['Overall score'].idxmax(),1:]).reset_index()
#                      Model  \
# 0  MLPRegressor()
# 1  RandomForestRegressor()
# 2  SVR()
#
#                                                        Parameters  \
# 0  { 'alpha': 0.01, 'hidden_layer_sizes': (50, 25)}
# 1  {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 2  {'C': 100, 'epsilon': 0.3, 'kernel': 'rbf'}
#
#    Number of features  Overall score    ME    SD   MASE
# 0  50                  7.73           0.63  9.45  93.65
# 1  100                 7.65          -0.06  7.29  92.60
# 2  20                  7.56          -1.73  9.65  91.61
# C:\Users\ilija\AppData\Local\Temp\ipykernel_2256\1944453032.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_results_sp = results_sp.groupby('Model').apply(lambda df: df.iloc[df['Overall score'].idxmax(),1:]).reset_index()
#                      Model  \
# 0  MLPRegressor()
# 1  RandomForestRegressor()
# 2  SVR()
#
#                                                           Parameters  \
# 0  { 'alpha': 0.01, 'hidden_layer_sizes': (25, 25)}
# 1  {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100}
# 2  {'C': 100, 'epsilon': 0.3, 'kernel': 'linear'}
#
#    Number of features  Overall score    ME     SD   MASE
# 0  50                  15.98         -0.11  19.64  90.91
# 1  100                 15.65          0.06  8.99   89.02
# 2  20                  16.09         -0.49  20.07  91.58
#                      Model  MAE_SP  ME_SP  SE_SP  MASE_SP  MAE_DP  ME_DP  \
# 0  MLPRegressor()           15.98  -0.11   19.64  90.91    7.73    0.63
# 1  RandomForestRegressor()  15.65   0.06   8.99   89.02    7.65   -0.06
# 2  SVR()                    16.09  -0.49   20.07  91.58    7.56   -1.73
#
#    SE_DP  MASE_DP
# 0  9.45   93.65
# 1  7.29   92.60
# 2  9.65   91.61

# %%
final_sensor = pd.concat([best_results_sensor,paper_sensor]).sort_values(by='Model')
final_sensor
# Out:
#                            Model  MAE_SP  ME_SP  SE_SP  MASE_SP  MAE_DP  \
# 0  MLPRegressor()                 15.98  -0.11   19.64  90.91    7.73
# 2  MLPRegressor()_paper           16.03  -0.50   20.10  91.03    7.77
# 1  RandomForestRegressor()        15.65   0.06   8.99   89.02    7.65
# 1  RandomForestRegressor()_paper  15.86  -0.12   19.85  90.08    7.66
# 2  SVR()                          16.09  -0.49   20.07  91.58    7.56
# 0  SVR()_paper                    15.60  -0.00   19.68  88.62    7.50
#
#    ME_DP  SE_DP  MASE_DP
# 0  0.63   9.45   93.65
# 2 -0.19   10.04  94.05
# 1 -0.06   7.29   92.60
# 1 -0.03   9.86   92.63
# 2 -1.73   9.65   91.61
# 0 -1.45   9.81   90.76

# %% [markdown]
# ## BCG data

# %%
data = {
    'Model': ['SVR()_paper', 'RandomForestRegressor()_paper', 'MLPRegressor()_paper'],
    'MAE_SP': [11.45, 12.88, 12.98],
    'ME_SE_SP': ['-0.79±15.56', '-1.46±17.75', '-0.27±16.35'],
    'MASE_SP': [93.07, 104.72, 105.50],
    'MAE_DP': [7.34, 7.89, 7.14],
    'ME_SE_DP': ['0.01±9.88', '-0.01±10.44', '0.03±9.28'],
    'MASE_DP': [92.75, 99.77, 90.24]
}
bcg = pd.DataFrame(data)

# Split the 'ME_SE' column into two separate columns, drop old ones and reorder df
bcg[['ME_SP', 'SE_SP']] = bcg['ME_SE_SP'].str.split('±', expand=True).astype(float)
bcg[['ME_DP', 'SE_DP']] = bcg['ME_SE_DP'].str.split('±', expand=True).astype(float)
bcg.drop(['ME_SE_SP', 'ME_SE_DP'], axis=1, inplace=True)
paper_bcg = bcg[['Model', 'MAE_SP', 'ME_SP', 'SE_SP', 'MASE_SP', 'MAE_DP', 'ME_DP', 'SE_DP', 'MASE_DP']]


paper_bcg
# Out:
#                            Model  MAE_SP  ME_SP  SE_SP  MASE_SP  MAE_DP  \
# 0  SVR()_paper                    11.45  -0.79   15.56  93.07    7.34
# 1  RandomForestRegressor()_paper  12.88  -1.46   17.75  104.72   7.89
# 2  MLPRegressor()_paper           12.98  -0.27   16.35  105.50   7.14
#
#    ME_DP  SE_DP  MASE_DP
# 0  0.01   9.88   92.75
# 1 -0.01   10.44  99.77
# 2  0.03   9.28   90.24

# %%
print('Results for the BCG dataset \n')
print('Results of DP')
display(results_dp_bcg.sort_values(by = 'Overall score'))
print('Results of SP')
display(results_sp_bcg.sort_values(by = 'Overall score'))
# Out:
# Results for the BCG dataset
#
# Results of DP
#                      Model  \
# 0  SVR()
# 1  MLPRegressor()
# 0  SVR()
# 0  SVR()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 0  SVR()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 1  MLPRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 2  RandomForestRegressor()
# 0  SVR()
# 0  SVR()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 2  RandomForestRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
#
#                                                         Parameters  \
# 0  {'C': 1, 'epsilon': 0.3, 'kernel': 'linear'}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (25,)}
# 0  {'C': 0.1, 'epsilon': 0.1, 'kernel': 'linear'}
# 0  {'C': 1, 'epsilon': 0.3, 'kernel': 'linear'}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (25,)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (50, 25)}
# 0  {'C': 0.1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 2  {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 50}
# 2  {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 2  {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (50,)}
# 2  {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 2  {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 2  {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 2  {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 0  {'C': 0.1, 'epsilon': 0.3, 'kernel': 'linear'}
# 0  {'C': 0.1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0  {'C': 0.1, 'epsilon': 0.3, 'kernel': 'rbf'}
# 2  {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0  {'C': 0.1, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0  {'C': 0.1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (25,)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (50,)}
# 2  {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50,)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50,)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (25,)}
#
#    Number of features  Overall score    ME    SD    MASE
# 0  16                  6.65          -0.29  6.95  89.67
# 1  16                  6.68           0.00  6.29  90.04
# 0  12                  6.87          -0.59  7.35  92.62
# 0  20                  6.89          -0.20  6.92  92.99
# 1  12                  6.89          -0.06  6.72  92.96
# 1  20                  6.93          -0.10  5.02  93.48
# 0  8                   7.30          -0.95  8.10  98.45
# 2  16                  7.31          -0.01  2.95  98.59
# 2  20                  7.42          -0.01  2.92  100.14
# 2  12                  7.42          -0.02  3.37  100.11
# 1  8                   7.58          -0.29  7.13  102.23
# 2  50                  7.61          -0.01  2.80  102.69
# 2  8                   7.66          -0.02  3.51  103.35
# 2  150                 7.71          -0.01  2.71  104.03
# 2  100                 7.75          -0.02  2.58  104.58
# 0  4                   7.75          -0.47  9.12  104.56
# 0  150                 7.77          -0.82  9.22  104.86
# 0  200                 7.78          -0.81  9.21  104.89
# 2  200                 7.78          -0.00  2.68  104.95
# 0  100                 7.80          -0.80  9.24  105.23
# 0  50                  7.82          -0.78  9.18  105.46
# 1  4                   7.93          -0.09  8.96  106.93
# 1  100                 7.93           0.27  4.97  106.98
# 2  4                   8.01          -0.01  4.82  108.05
# 1  50                  8.01          -0.20  5.35  108.00
# 1  200                 8.03          -0.24  4.50  108.35
# 1  150                 8.17           0.08  5.36  110.24
# Results of SP
#                      Model  \
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 1  MLPRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
#
#                                                          Parameters  \
# 0  {'C': 0.1, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0  {'C': 0.1, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0  {'C': 0.1, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0  {'C': 0.1, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0  {'C': 0.1, 'epsilon': 0.3, 'kernel': 'linear'}
# 0  {'C': 0.1, 'epsilon': 0.2, 'kernel': 'linear'}
# 0  {'C': 0.1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0  {'C': 0.1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0  {'C': 0.1, 'epsilon': 0.2, 'kernel': 'linear'}
# 2  {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 2  {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
# 2  {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 100}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (25, 25)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (25,)}
# 2  {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 2  {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 100}
# 2  {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 50}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (25,)}
# 2  {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 2  {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 2  {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (25,)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (25,)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (25,)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (25,)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (50,)}
#
#    Number of features  Overall score    ME     SD    MASE
# 0  200                 11.34         -0.87  15.07  101.96
# 0  50                  11.35         -1.07  15.24  102.11
# 0  150                 11.35         -0.99  15.15  102.11
# 0  100                 11.36         -0.99  15.21  102.17
# 0  8                   11.41         -0.03  14.37  102.60
# 0  4                   11.41         -1.00  15.27  102.58
# 0  12                  11.49         -0.55  14.21  103.29
# 0  20                  11.52         -0.40  13.99  103.56
# 0  16                  11.52         -0.04  14.16  103.62
# 2  20                  11.98          0.02  4.97   107.76
# 2  16                  12.06          0.01  2.32   108.44
# 2  50                  12.09         -0.01  2.42   108.75
# 1  4                   12.11         -0.17  14.97  108.88
# 1  8                   12.20         -0.10  13.08  109.73
# 2  100                 12.23          0.04  4.03   109.97
# 2  200                 12.26         -0.00  2.42   110.26
# 2  150                 12.30          0.03  4.08   110.63
# 1  12                  12.40         -0.00  12.95  111.54
# 2  12                  12.44         -0.00  5.26   111.85
# 2  4                   12.47         -0.08  7.62   112.10
# 2  8                   12.68          0.01  4.21   114.00
# 1  16                  12.93         -0.03  12.32  116.30
# 1  20                  12.96         -0.03  11.94  116.51
# 1  50                  13.14         -0.97  7.95   118.16
# 1  100                 13.34         -0.19  9.49   119.93
# 1  150                 13.39         -0.35  8.29   120.39
# 1  200                 13.47          0.38  9.18   121.18

# %%
best_results_bcg = process(results_sp_bcg,results_dp_bcg)
best_results_bcg
# Out:
# C:\Users\ilija\AppData\Local\Temp\ipykernel_2256\1944453032.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_results_dp = results_dp.groupby('Model').apply(lambda df: df.iloc[df['Overall score'].idxmax(),1:]).reset_index()
#                      Model  \
# 0  MLPRegressor()
# 1  RandomForestRegressor()
# 2  SVR()
#
#                                                        Parameters  \
# 0  { 'alpha': 0.1, 'hidden_layer_sizes': (50,)}
# 1  {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 2  {'C': 1, 'epsilon': 0.3, 'kernel': 'linear'}
#
#    Number of features  Overall score    ME    SD    MASE
# 0  50                  8.01          -0.20  5.35  108.00
# 1  100                 7.75          -0.02  2.58  104.58
# 2  20                  6.89          -0.20  6.92  92.99
# C:\Users\ilija\AppData\Local\Temp\ipykernel_2256\1944453032.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_results_sp = results_sp.groupby('Model').apply(lambda df: df.iloc[df['Overall score'].idxmax(),1:]).reset_index()
#                      Model  \
# 0  MLPRegressor()
# 1  RandomForestRegressor()
# 2  SVR()
#
#                                                       Parameters  \
# 0  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1  {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 2  {'C': 0.1, 'epsilon': 0.1, 'kernel': 'rbf'}
#
#    Number of features  Overall score    ME     SD    MASE
# 0  50                  13.14         -0.97  7.95   118.16
# 1  100                 12.23          0.04  4.03   109.97
# 2  20                  11.52         -0.40  13.99  103.56
#                      Model  MAE_SP  ME_SP  SE_SP  MASE_SP  MAE_DP  ME_DP  \
# 0  MLPRegressor()           13.14  -0.97   7.95   118.16   8.01   -0.20
# 1  RandomForestRegressor()  12.23   0.04   4.03   109.97   7.75   -0.02
# 2  SVR()                    11.52  -0.40   13.99  103.56   6.89   -0.20
#
#    SE_DP  MASE_DP
# 0  5.35   108.00
# 1  2.58   104.58
# 2  6.92   92.99

# %%
final_bcg = pd.concat([best_results_bcg,paper_bcg]).sort_values(by='Model')
final_bcg
# Out:
#                            Model  MAE_SP  ME_SP  SE_SP  MASE_SP  MAE_DP  \
# 0  MLPRegressor()                 13.14  -0.97   7.95   118.16   8.01
# 2  MLPRegressor()_paper           12.98  -0.27   16.35  105.50   7.14
# 1  RandomForestRegressor()        12.23   0.04   4.03   109.97   7.75
# 1  RandomForestRegressor()_paper  12.88  -1.46   17.75  104.72   7.89
# 2  SVR()                          11.52  -0.40   13.99  103.56   6.89
# 0  SVR()_paper                    11.45  -0.79   15.56  93.07    7.34
#
#    ME_DP  SE_DP  MASE_DP
# 0 -0.20   5.35   108.00
# 2  0.03   9.28   90.24
# 1 -0.02   2.58   104.58
# 1 -0.01   10.44  99.77
# 2 -0.20   6.92   92.99
# 0  0.01   9.88   92.75

# %% [markdown]
# ## PPGBP

# %%
data = {
    'Model': ['SVR()_paper', 'RandomForestRegressor()_paper', 'MLPRegressor()_paper'],
    'MAE_SP': [13.15, 13.17, 13.38],
    'ME_SE_SP': ['-0.64±17.05', '0.02±16.81', '-0.13±17.09'],
    'MASE_SP': [80.29, 80.42, 81.69],
    'MAE_DP': [8.04, 8.12, 8.21],
    'ME_SE_DP': ['-0.22±10.14', '0.19±10.17', '-0.16±10.40'],
    'MASE_DP': [90.90, 91.76, 92.77]
}

ppgbp_paper = pd.DataFrame(data)

ppgbp_paper[['ME_SP', 'SE_SP']] = ppgbp_paper['ME_SE_SP'].str.split('±', expand=True).astype(float)
ppgbp_paper[['ME_DP', 'SE_DP']] = ppgbp_paper['ME_SE_DP'].str.split('±', expand=True).astype(float)

ppgbp_paper.drop(['ME_SE_SP', 'ME_SE_DP'], axis=1, inplace=True)

paper_ppgbp = ppgbp_paper[['Model', 'MAE_SP', 'ME_SP', 'SE_SP', 'MASE_SP', 'MAE_DP', 'ME_DP', 'SE_DP', 'MASE_DP']]

paper_ppgbp
# Out:
#                            Model  MAE_SP  ME_SP  SE_SP  MASE_SP  MAE_DP  \
# 0  SVR()_paper                    13.15  -0.64   17.05  80.29    8.04
# 1  RandomForestRegressor()_paper  13.17   0.02   16.81  80.42    8.12
# 2  MLPRegressor()_paper           13.38  -0.13   17.09  81.69    8.21
#
#    ME_DP  SE_DP  MASE_DP
# 0 -0.22   10.14  90.90
# 1  0.19   10.17  91.76
# 2 -0.16   10.40  92.77

# %%
print('Results for the PPGBP dataset \n')
print('Results of DP')
display(results_dp_ppgbp.sort_values(by = 'Overall score'))
print('Results of SP')
display(results_sp_ppgbp.sort_values(by = 'Overall score'))
# Out:
# Results for the PPGBP dataset
#
# Results of DP
#                      Model  \
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 0  SVR()
# 2  RandomForestRegressor()
# 0  SVR()
# 0  SVR()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 0  SVR()
# 0  SVR()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
#
#                                                           Parameters  \
# 2  {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 50}
# 2  {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 50}
# 2  {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 2  {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100}
# 2  {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 2  {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 50}
# 0  {'C': 100, 'epsilon': 0.2, 'kernel': 'rbf'}
# 0  {'C': 100, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0  {'C': 100, 'epsilon': 0.1, 'kernel': 'linear'}
# 0  {'C': 100, 'epsilon': 0.1, 'kernel': 'linear'}
# 2  {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 100}
# 2  {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 50}
# 0  {'C': 10, 'epsilon': 0.2, 'kernel': 'linear'}
# 2  {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 50}
# 0  {'C': 0.1, 'epsilon': 0.3, 'kernel': 'linear'}
# 0  {'C': 0.1, 'epsilon': 0.1, 'kernel': 'linear'}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (50, 25)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (25, 25)}
# 0  {'C': 10, 'epsilon': 0.3, 'kernel': 'rbf'}
# 0  {'C': 0.1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (25,)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (25,)}
#
#    Number of features  Overall score    ME     SD    MASE
# 2  20                  7.82          -0.04  3.84   88.43
# 2  16                  7.84           0.06  4.31   88.73
# 2  50                  7.87          -0.02  4.27   89.04
# 2  12                  7.99          -0.01  5.11   90.36
# 2  100                 8.00           0.08  3.98   90.54
# 2  8                   8.06           0.03  4.88   91.20
# 0  20                  8.06          -1.19  10.01  91.24
# 0  16                  8.07          -1.10  10.03  91.30
# 0  4                   8.08          -1.29  10.17  91.38
# 0  8                   8.11          -1.32  10.09  91.73
# 2  150                 8.12          -0.00  3.77   91.83
# 2  200                 8.14           0.09  4.54   92.14
# 0  12                  8.20          -1.38  10.07  92.76
# 2  4                   8.27           0.00  6.33   93.55
# 0  50                  8.29          -1.23  10.11  93.81
# 0  100                 8.37          -1.17  9.91   94.70
# 1  20                  8.60          -0.94  10.51  97.30
# 1  16                  8.62           0.06  10.60  97.50
# 1  100                 8.64           0.30  9.13   97.78
# 0  150                 8.65          -1.44  10.15  97.86
# 0  200                 8.68          -1.41  11.12  98.21
# 1  50                  8.72          -0.82  10.02  98.64
# 1  12                  8.75          -0.62  10.81  98.97
# 1  150                 8.93           0.29  9.58   101.02
# 1  8                   8.98          -0.55  11.00  101.59
# 1  4                   9.01           0.47  11.25  101.95
# 1  200                 9.12          -0.14  9.39   103.13
# Results of SP
#                      Model  \
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 2  RandomForestRegressor()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 0  SVR()
# 2  RandomForestRegressor()
# 0  SVR()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 0  SVR()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 0  SVR()
# 1  MLPRegressor()
# 0  SVR()
# 1  MLPRegressor()
# 1  MLPRegressor()
# 1  MLPRegressor()
#
#                                                           Parameters  \
# 2  {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100}
# 2  {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100}
# 2  {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 2  {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 100}
# 2  {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 2  {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 50}
# 2  {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 2  {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100}
# 0  {'C': 100, 'epsilon': 0.3, 'kernel': 'linear'}
# 0  {'C': 100, 'epsilon': 0.1, 'kernel': 'linear'}
# 0  {'C': 100, 'epsilon': 0.2, 'kernel': 'linear'}
# 0  {'C': 100, 'epsilon': 0.1, 'kernel': 'linear'}
# 0  {'C': 100, 'epsilon': 0.3, 'kernel': 'linear'}
# 2  {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0  {'C': 1, 'epsilon': 0.3, 'kernel': 'linear'}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50,)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (50, 25)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 0  {'C': 1, 'epsilon': 0.2, 'kernel': 'linear'}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (50,)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 0  {'C': 100, 'epsilon': 0.3, 'kernel': 'linear'}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (25,)}
# 0  {'C': 0.1, 'epsilon': 0.3, 'kernel': 'linear'}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1  { 'alpha': 0.01, 'hidden_layer_sizes': (50, 25)}
# 1  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
#
#    Number of features  Overall score    ME     SD    MASE
# 2  12                  12.89         -0.06  8.68   78.79
# 2  20                  12.91         -0.05  8.16   78.91
# 2  16                  12.94         -0.08  7.89   79.06
# 2  150                 12.98          0.05  6.01   79.32
# 2  50                  13.00         -0.05  6.75   79.46
# 2  100                 13.02          0.14  7.68   79.58
# 2  200                 13.11          0.11  7.11   80.09
# 2  8                   13.14          0.05  8.87   80.30
# 0  16                  13.22         -0.90  16.76  80.81
# 0  20                  13.27         -0.70  16.82  81.12
# 0  12                  13.40         -1.08  16.92  81.89
# 0  50                  13.64         -0.64  16.33  83.38
# 0  8                   13.65         -1.12  17.19  83.44
# 2  4                   13.82          0.02  11.07  84.44
# 0  100                 13.83         -1.16  16.35  84.49
# 1  100                 13.88          0.75  16.77  84.79
# 1  50                  14.03          2.33  17.08  85.75
# 1  20                  14.08         -1.19  18.79  86.03
# 0  150                 14.27         -1.20  16.23  87.22
# 1  150                 14.29         -0.15  16.10  87.33
# 1  16                  14.31          1.06  18.34  87.42
# 0  4                   14.32         -1.29  18.20  87.50
# 1  200                 14.51          0.81  16.36  88.68
# 0  200                 14.66         -1.12  16.63  89.58
# 1  12                  14.76         -1.90  18.89  90.22
# 1  8                   17.17          1.01  19.60  104.95
# 1  4                   17.94         -0.17  22.20  109.62

# %%
best_results_ppgbp = process(results_sp_ppgbp,results_dp_ppgbp)
best_results_ppgbp
# Out:
# C:\Users\ilija\AppData\Local\Temp\ipykernel_2256\1944453032.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_results_dp = results_dp.groupby('Model').apply(lambda df: df.iloc[df['Overall score'].idxmax(),1:]).reset_index()
#                      Model  \
# 0  MLPRegressor()
# 1  RandomForestRegressor()
# 2  SVR()
#
#                                                           Parameters  \
# 0  { 'alpha': 0.1, 'hidden_layer_sizes': (50, 25)}
# 1  {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 100}
# 2  {'C': 100, 'epsilon': 0.1, 'kernel': 'linear'}
#
#    Number of features  Overall score    ME     SD    MASE
# 0  8                   8.98          -0.55  11.00  101.59
# 1  12                  7.99          -0.01  5.11   90.36
# 2  4                   8.08          -1.29  10.17  91.38
# C:\Users\ilija\AppData\Local\Temp\ipykernel_2256\1944453032.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   best_results_sp = results_sp.groupby('Model').apply(lambda df: df.iloc[df['Overall score'].idxmax(),1:]).reset_index()
#                      Model  \
# 0  MLPRegressor()
# 1  RandomForestRegressor()
# 2  SVR()
#
#                                                         Parameters  \
# 0  { 'alpha': 0.01, 'hidden_layer_sizes': (50, 25)}
# 1  {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 100}
# 2  {'C': 100, 'epsilon': 0.3, 'kernel': 'linear'}
#
#    Number of features  Overall score    ME     SD    MASE
# 0  8                   17.17          1.01  19.60  104.95
# 1  12                  12.89         -0.06  8.68   78.79
# 2  4                   14.32         -1.29  18.20  87.50
#                      Model  MAE_SP  ME_SP  SE_SP  MASE_SP  MAE_DP  ME_DP  \
# 0  MLPRegressor()           17.17   1.01   19.60  104.95   8.98   -0.55
# 1  RandomForestRegressor()  12.89  -0.06   8.68   78.79    7.99   -0.01
# 2  SVR()                    14.32  -1.29   18.20  87.50    8.08   -1.29
#
#    SE_DP  MASE_DP
# 0  11.00  101.59
# 1  5.11   90.36
# 2  10.17  91.38

# %%
final_ppgbp = pd.concat([best_results_ppgbp,paper_ppgbp]).sort_values(by='Model')
final_ppgbp
# Out:
#                            Model  MAE_SP  ME_SP  SE_SP  MASE_SP  MAE_DP  \
# 0  MLPRegressor()                 17.17   1.01   19.60  104.95   8.98
# 2  MLPRegressor()_paper           13.38  -0.13   17.09  81.69    8.21
# 1  RandomForestRegressor()        12.89  -0.06   8.68   78.79    7.99
# 1  RandomForestRegressor()_paper  13.17   0.02   16.81  80.42    8.12
# 2  SVR()                          14.32  -1.29   18.20  87.50    8.08
# 0  SVR()_paper                    13.15  -0.64   17.05  80.29    8.04
#
#    ME_DP  SE_DP  MASE_DP
# 0 -0.55   11.00  101.59
# 2 -0.16   10.40  92.77
# 1 -0.01   5.11   90.36
# 1  0.19   10.17  91.76
# 2 -1.29   10.17  91.38
# 0 -0.22   10.14  90.90
